# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])


plt.figure(figsize = (10, 10))
plt.plot(xpoints, ypoints, 'bo-')
plt.title("sport calorie")
plt.xlabel("sports")
plt.ylabel("calorie")
plt.plot(ypoints, 'o--k')
plt.xticks(range(10))
plt.yticks(range(15))
plt.show()

plt.grid()

# %%
x = np.arange(0, 2, 0.2)
plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color ='forestgreen', marker = '^', markersize = 9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.show()

# %%
N = 10
x = np.random.randint(10,size = N)
y = np.random.randint(10,size = N)

plt.scatter(x, y, c = 'red')
plt.show()
x
# Out:
# array([8, 9, 1, 5, 3, 7, 5, 3, 9, 5])

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
x
# Out:
# array([176.02087608, 169.62333272, 167.78835671, 173.3522692 ,
#        169.35105806, 155.79914936, 171.15920049, 159.4176145 ,
#        160.95889638, 161.5090719 , 179.93851048, 174.92640328,
#        170.98188466, 146.70907089, 164.13629921, 168.65494867,
#        155.16245833, 155.22926773, 169.95834381, 178.14317799,
#        147.78188503, 178.68934481, 154.35443785, 193.36849605,
#        169.1071635 , 178.19209708, 167.91420155, 179.65249924,
#        166.16378323, 166.93838763, 169.15889055, 163.34542926,
#        173.25287303, 175.21648134, 174.21888143, 190.73569462,
#        180.60180569, 167.36197867, 158.72966032, 173.2145342 ,
#        175.61107727, 171.47941441, 173.10712274, 182.86032335,
#        168.58125289, 166.79391858, 161.68921869, 169.20094426,
#        170.57276753, 175.84148372, 174.80547299, 152.21654359,
#        165.54424967, 186.9905253 , 183.45238503, 135.95838282,
#        141.66426817, 154.94026389, 160.63655162, 155.76832888,
#        144.59503108, 163.17729396, 164.15347582, 167.50019363,
#        164.09150248, 179.93112761, 164.53721199, 169.92817867,
#        163.34353118, 179.39772814, 161.2719525 , 177.08260808,
#        163.77872382, 173.92744114, 166.94763012, 173.80781725,
#        170.81455421, 157.3434252 , 171.76972548, 166.61808027,
#        181.98541497, 167.67034092, 188.23569196, 168.77586339,
#        166.83367616, 182.30886823, 167.05803048, 175.07658936,
#        172.75588309, 169.65071111, 170.87643855, 159.60192365,
